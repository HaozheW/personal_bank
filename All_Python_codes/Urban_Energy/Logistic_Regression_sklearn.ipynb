# %%
import collections
import pandas as pd
import numpy as np
from datetime import datetime
import os
import statsmodels.api as sm
import pylab as pl
from patsy import dmatrices
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.cross_validation import cross_val_score
import patsy

pd.set_option('display.max_columns', 100)#this allowed 100 columns to be shown in ipython notebook

# %%
pathname = "C:\Users\William\Documents\GitHub\urban_project_Haozhe"

# %%
# read data into pandas dataframe and convert column names to upper case
def read_data(pname,fname):
	if fname.endswith('.csv'):
		df = pd.DataFrame.from_csv(os.path.join(pname,fname),index_col=None)
		df = df.rename(columns=lambda x: x.upper(),inplace=False)
		return df
	elif fname.endswith('.xlsx'):
		df = pd.io.excel.read_excel(os.path.join(pname,fname),sheetname=0,			index_col=None)
		df = df.rename(columns=lambda x: x.upper(),inplace=False)
		return df
    
def merge_df(df,map,on):
    df = pd.DataFrame.merge(df,map,how='left',on=on)
    return df

def balanced_subsample(x,y,subsample_size=1.0):

    class_xs = []
    min_elems = None

    for yi in np.unique(y):
        elems = x[(y == yi)]
        class_xs.append((yi, elems))
        if min_elems == None or elems.shape[0] < min_elems:
            min_elems = elems.shape[0]

    use_elems = min_elems
    if subsample_size < 1:
        use_elems = int(min_elems*subsample_size)

    xs = []
    ys = []

    for ci,this_xs in class_xs:
        if len(this_xs) > use_elems:
            np.random.shuffle(this_xs)

        x_ = this_xs[:use_elems]
        y_ = np.empty(use_elems)
        y_.fill(ci)

        xs.append(x_)
        ys.append(y_)

    xs = np.concatenate(xs)
    ys = np.concatenate(ys)

    return xs,ys

# %%
# read data into pandas dataframes
audit = read_data(pathname,"sample0723_HW_3joins.csv")
print "total number of audits:", len(audit)
print "Data read into dataframes"
audit = audit.rename(columns={'AUDIT CONTRACTOR': 'CONTRACTOR'})
#audit.head()
# Out:
# total number of audits: 38887
# Data read into dataframes

# %%
#audit = audit[audit.MEDIANHOUSEVALUE != 0]
#audit = audit[audit.MEDIANHOUSEVALUE != '.']
#del audit['REGION']



audit.sort(['MEDIAN_VALUE'])
#print audit.head()
audit.insert(0, 'CONVERT', audit['CLASS'])
del audit['CLASS']
audit.insert(1, 'SQFT_LN', np.log(audit['SQFT']))
audit.insert(2, 'ANNUALPRIMARYUSAGE_LN', np.log(audit['ANNUALPRIMARYUSAGE']))
audit.insert(3, 'MEDIANHOUSEVALUE_LN', np.log(audit['MEDIAN_VALUE']))
audit.insert(4, 'ANNUALELECTRICUSAGE_LN', np.log(audit['ANNUALELECTRICUSAGE']*3.412))# kWh convert to MBTU
audit.insert(5, 'ENERGY_TOTAL_USE_INTENSITY', (audit['ANNUALELECTRICUSAGE']*3.412+audit['ANNUALPRIMARYUSAGE'])/audit['SQFT'])
audit.insert(6, 'ENERGY_TOTAL_USE_INTENSITY_LN', np.log(audit['ENERGY_TOTAL_USE_INTENSITY']))
audit.insert(7, 'MEDIAN_HOUSE_AGE_LN', np.log(audit['MEDIAN_HOUSEAGE']))
audit.insert(8, 'MEDIAN_HH_INCOME_LN', np.log(audit['MEDIAN_HH_INCOME']))



audit = audit[audit['ENERGY_TOTAL_USE_INTENSITY'] >= 5]
audit = audit[audit['ENERGY_TOTAL_USE_INTENSITY'] <= 500]
audit = audit.dropna()

# %%
count = audit.groupby(['CONTRACTOR']).count().sort('CONVERT')
count.insert(0, 'COUNT', count['CONVERT'])
count = count['COUNT']
count = pd.DataFrame(count)
count = count[count.COUNT > 25]
#rcParams['figure.figsize'] = 40, 24
#count.plot(kind = 'bar')

count.loc[count['COUNT']<6000, 'CONTRACTOR_CLASS'] = 10
count.loc[count['COUNT']<3889, 'CONTRACTOR_CLASS'] = 9
count.loc[count['COUNT']<790, 'CONTRACTOR_CLASS'] = 8
count.loc[count['COUNT']<477, 'CONTRACTOR_CLASS'] = 7
count.loc[count['COUNT']<298, 'CONTRACTOR_CLASS'] = 6
count.loc[count['COUNT']<181, 'CONTRACTOR_CLASS'] = 5
count.loc[count['COUNT']<101, 'CONTRACTOR_CLASS'] = 4
count.loc[count['COUNT']<71, 'CONTRACTOR_CLASS'] = 3
count.loc[count['COUNT']<60, 'CONTRACTOR_CLASS'] = 2
count.loc[count['COUNT']<40, 'CONTRACTOR_CLASS'] = 1

count.reset_index(level=0, inplace=True)

count.to_csv('C:\Users\William\Documents\GitHub\urban_project_Haozhe\contractor_count.csv', index = False)

# %%
merged_audit = merge_df(audit, count, 'CONTRACTOR')
del merged_audit['COUNT']
merged_audit = merged_audit.dropna(subset=['CONTRACTOR_CLASS'], how = 'any')
#print merged_audit.head()
del merged_audit['CONTRACTOR']

merged_audit = merged_audit[merged_audit['CONTRACTOR_CLASS'] < 10 ]

merged_audit.to_csv('C:\Users\William\Documents\GitHub\urban_project_Haozhe\sample_HW_contractor_count0724.csv', index = False)

# %%
y, X = dmatrices('CONVERT ~ SQFT_LN + MEDIAN_HOUSE_AGE_LN + MEDIAN_HH_INCOME_LN + ANNUALPRIMARYUSAGE_LN + MEDIANHOUSEVALUE_LN + \
                C(HOMETYPE) + C(INCOME)+C(INCOME)+C(PRIMARYFUELTYPE)+C(ZONE)+C(CENTRALAIR)+C(CONTRACTOR_CLASS)',
                  merged_audit, return_type="dataframe")
print X.columns
#y_list = y.values
#X_list = X.values
#X_list
# Out:
# Index([u'Intercept', u'C(HOMETYPE)[T.2-Unit]', u'C(HOMETYPE)[T.3-Unit]', u'C(HOMETYPE)[T.4-Unit]', u'C(HOMETYPE)[T.Condo]', u'C(HOMETYPE)[T.Mobile Home]', u'C(HOMETYPE)[T.NFP 4-Unit]', u'C(HOMETYPE)[T.Single Family]', u'C(HOMETYPE)[T.Single Family > 3500]', u'C(HOMETYPE)[T.Townhouse - Duplex > 3500]', u'C(INCOME)[T.&le;250% AMI]', u'C(INCOME)[T.&le;300% AMI]', u'C(INCOME)[T.&le;350% AMI]', u'C(INCOME)[T.&le;400% AMI]', u'C(PRIMARYFUELTYPE)[T.Electric]', u'C(PRIMARYFUELTYPE)[T.Gas]', u'C(PRIMARYFUELTYPE)[T.Kerosene]', u'C(PRIMARYFUELTYPE)[T.Oil]', u'C(PRIMARYFUELTYPE)[T.Pellets]', u'C(PRIMARYFUELTYPE)[T.Propane]', u'C(PRIMARYFUELTYPE)[T.Wood]', u'C(ZONE)[T.5.0]', u'C(ZONE)[T.6.0]', u'C(CENTRALAIR)[T.Yes]', u'C(CONTRACTOR_CLASS)[T.2.0]', u'C(CONTRACTOR_CLASS)[T.3.0]', u'C(CONTRACTOR_CLASS)[T.4.0]', u'C(CONTRACTOR_CLASS)[T.5.0]', u'C(CONTRACTOR_CLASS)[T.6.0]', u'C(CONTRACTOR_CLASS)[T.7.0]', u'C(CONTRACTOR_CLASS)[T.8.0]', u'C(CONTRACTOR_CLASS)[T.9.0]', u'SQFT_LN', u'MEDIAN_HOUSE_AGE_LN', u'MEDIAN_HH_INCOME_LN', u'ANNUALPRIMARYUSAGE_LN', u'MEDIANHOUSEVALUE_LN'], dtype='object')

# %%
fitting = sm.Logit(y, X).fit()
fitting.summary()
# fit the model
#data
#result = logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.257037
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                CONVERT   No. Observations:                26107
# Model:                          Logit   Df Residuals:                    26070
# Method:                           MLE   Df Model:                           36
# Date:                Thu, 24 Jul 2014   Pseudo R-squ.:                 0.01577
# Time:                        22:17:19   Log-Likelihood:                -6710.5
# converged:                       True   LL-Null:                       -6818.0
#                                         LLR p-value:                 2.352e-27
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    4.2621      1.892      2.253      0.024         0.554     7.970
# C(HOMETYPE)[T.2-Unit]                       -1.6663      1.019     -1.635      0.102        -3.664     0.331
# C(HOMETYPE)[T.3-Unit]                       -1.7147      1.058     -1.621      0.105        -3.788     0.359
# C(HOMETYPE)[T.4-Unit]                       -0.7070      1.441     -0.491      0.624        -3.531     2.117
# C(HOMETYPE)[T.Condo]                        -0.4625      1.437     -0.322      0.748        -3.279     2.354
# C(HOMETYPE)[T.Mobile Home]                  -1.5162      1.211     -1.252      0.211        -3.890     0.857
# C(HOMETYPE)[T.NFP 4-Unit]                   -4.1846      1.743     -2.400      0.016        -7.601    -0.768
# C(HOMETYPE)[T.Single Family]                -1.1883      1.013     -1.173      0.241        -3.175     0.798
# C(HOMETYPE)[T.Single Family > 3500]         -1.4662      1.025     -1.430      0.153        -3.475     0.543
# C(HOMETYPE)[T.Townhouse - Duplex > 3500]    -1.8389      1.475     -1.246      0.213        -4.731     1.053
# C(INCOME)[T.&le;250% AMI]                   -0.1273      0.117     -1.090      0.276        -0.356     0.102
# C(INCOME)[T.&le;300% AMI]                   -0.0835      0.208     -0.401      0.688        -0.492     0.325
# C(INCOME)[T.&le;350% AMI]                   -0.4482      0.269     -1.668      0.095        -0.975     0.079
# C(INCOME)[T.&le;400% AMI]                   -0.9551      0.257     -3.715      0.000        -1.459    -0.451
# C(PRIMARYFUELTYPE)[T.Electric]              -0.9288      1.119     -0.830      0.406        -3.121     1.263
# C(PRIMARYFUELTYPE)[T.Gas]                    0.1762      1.060      0.166      0.868        -1.901     2.253
# C(PRIMARYFUELTYPE)[T.Kerosene]              -0.5617      1.157     -0.485      0.627        -2.829     1.706
# C(PRIMARYFUELTYPE)[T.Oil]                    0.0574      1.060      0.054      0.957        -2.021     2.136
# C(PRIMARYFUELTYPE)[T.Pellets]                0.0091      1.285      0.007      0.994        -2.510     2.528
# C(PRIMARYFUELTYPE)[T.Propane]               -0.0242      1.069     -0.023      0.982        -2.120     2.072
# C(PRIMARYFUELTYPE)[T.Wood]                  -0.6963      1.115     -0.624      0.532        -2.882     1.490
# C(ZONE)[T.5.0]                              -0.1845      0.102     -1.811      0.070        -0.384     0.015
# C(ZONE)[T.6.0]                               0.2364      0.121      1.961      0.050         0.000     0.473
# C(CENTRALAIR)[T.Yes]                        -0.1252      0.056     -2.231      0.026        -0.235    -0.015
# C(CONTRACTOR_CLASS)[T.2.0]                  -0.2538      0.148     -1.709      0.087        -0.545     0.037
# C(CONTRACTOR_CLASS)[T.3.0]                   0.3729      0.199      1.877      0.061        -0.016     0.762
# C(CONTRACTOR_CLASS)[T.4.0]                   0.0598      0.150      0.399      0.690        -0.234     0.354
# C(CONTRACTOR_CLASS)[T.5.0]                   0.2028      0.149      1.360      0.174        -0.089     0.495
# C(CONTRACTOR_CLASS)[T.6.0]                   0.2371      0.135      1.760      0.078        -0.027     0.501
# C(CONTRACTOR_CLASS)[T.7.0]                   0.1834      0.138      1.330      0.183        -0.087     0.454
# C(CONTRACTOR_CLASS)[T.8.0]                  -0.0515      0.150     -0.344      0.731        -0.345     0.242
# C(CONTRACTOR_CLASS)[T.9.0]                  -0.3055      0.131     -2.336      0.020        -0.562    -0.049
# SQFT_LN                                      0.1549      0.082      1.882      0.060        -0.006     0.316
# MEDIAN_HOUSE_AGE_LN                         -0.5045      0.098     -5.127      0.000        -0.697    -0.312
# MEDIAN_HH_INCOME_LN                          0.1027      0.099      1.040      0.299        -0.091     0.296
# ANNUALPRIMARYUSAGE_LN                        0.0343      0.028      1.242      0.214        -0.020     0.088
# MEDIANHOUSEVALUE_LN                         -0.0850      0.083     -1.030      0.303        -0.247     0.077
# ============================================================================================================
# """

# %%
# flatten y into a 1-D array
y = np.ravel(y)

# %%
# instantiate a logistic regression model, and fit with X and y
model = LogisticRegression()
model = model.fit(X, y)



#Returns the coefficient of determination R^2 of the prediction.
# check the accuracy on the training set
print 'The coefficient of determination R^2 of the prediction is: ', model.score(X, y)
# Out:
# The coefficient of determination R^2 of the prediction is:  0.927069368369

# %%
#Predict confidence scores for samples.
model.decision_function(X)
# Out:
# array([ 2.89627332,  2.86827342,  3.02218897, ...,  2.0713604 ,
#         2.37612003,  2.0446841 ])

# %%
# what percentage had retrofit project?
y.mean()
# Out:
# 0.92706936836863674

# %%
# examine the coefficients
pd.DataFrame(zip(X.columns, np.transpose(model.coef_)))
# Out:
#                                            0                   1
# 0                                  Intercept    [0.790609822485]
# 1                      C(HOMETYPE)[T.2-Unit]   [-0.404631906259]
# 2                      C(HOMETYPE)[T.3-Unit]   [-0.416457275036]
# 3                      C(HOMETYPE)[T.4-Unit]    [0.282782403052]
# 4                       C(HOMETYPE)[T.Condo]     [0.42974838779]
# 5                 C(HOMETYPE)[T.Mobile Home]   [-0.170894830419]
# 6                  C(HOMETYPE)[T.NFP 4-Unit]   [-0.752697195409]
# 7               C(HOMETYPE)[T.Single Family]   [0.0691531241072]
# 8        C(HOMETYPE)[T.Single Family > 3500]   [-0.231150382041]
# 9   C(HOMETYPE)[T.Townhouse - Duplex > 3500]   [-0.243735102811]
# 10                 C(INCOME)[T.&le;250% AMI]   [-0.132840600395]
# 11                 C(INCOME)[T.&le;300% AMI]  [-0.0941536868668]
# 12                 C(INCOME)[T.&le;350% AMI]   [-0.427523384944]
# 13                 C(INCOME)[T.&le;400% AMI]   [-0.917961906896]
# 14            C(PRIMARYFUELTYPE)[T.Electric]   [-0.521522686168]
# 15                 C(PRIMARYFUELTYPE)[T.Gas]    [0.518809589936]
# 16            C(PRIMARYFUELTYPE)[T.Kerosene]   [-0.175684801569]
# 17                 C(PRIMARYFUELTYPE)[T.Oil]    [0.396177755297]
# 18             C(PRIMARYFUELTYPE)[T.Pellets]    [0.230413966513]
# 19             C(PRIMARYFUELTYPE)[T.Propane]    [0.314082803121]
# 20                C(PRIMARYFUELTYPE)[T.Wood]   [-0.303180421157]
# 21                            C(ZONE)[T.5.0]    [-0.13495286993]
# 22                            C(ZONE)[T.6.0]    [0.287512377693]
# 23                      C(CENTRALAIR)[T.Yes]   [-0.126114584785]
# 24                C(CONTRACTOR_CLASS)[T.2.0]   [-0.237480754897]
# 25                C(CONTRACTOR_CLASS)[T.3.0]    [0.375617066355]
# 26                C(CONTRACTOR_CLASS)[T.4.0]   [0.0671160953579]
# 27                C(CONTRACTOR_CLASS)[T.5.0]    [0.210974856208]
# 28                C(CONTRACTOR_CLASS)[T.6.0]    [0.244999327526]
# 29                C(CONTRACTOR_CLASS)[T.7.0]    [0.195277515135]
# 30                C(CONTRACTOR_CLASS)[T.8.0]    [-0.03871920208]
# 31                C(CONTRACTOR_CLASS)[T.9.0]   [-0.289741697912]
# 32                                   SQFT_LN    [0.171013652515]
# 33                       MEDIAN_HOUSE_AGE_LN   [-0.443699335987]
# 34                       MEDIAN_HH_INCOME_LN    [0.137185552042]
# 35                     ANNUALPRIMARYUSAGE_LN    [0.034585598333]
# 36                       MEDIANHOUSEVALUE_LN  [-0.0613014579798]
#
# [37 rows x 2 columns]

# %%
# evaluate the model by splitting into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=54)
model2 = LogisticRegression(class_weight = 'auto')
model2.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight='auto', dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
# predict class labels for the test set
predicted = model2.predict(X_test)
print predicted
# Out:
# [ 1.  1.  1. ...,  1.  1.  0.]

# %%
# generate class probabilities
probs = model2.predict_proba(X_test)
print probs
# Out:
# [[ 0.45515195  0.54484805]
#  [ 0.30463729  0.69536271]
#  [ 0.38722718  0.61277282]
#  ...,
#  [ 0.47743619  0.52256381]
#  [ 0.43967034  0.56032966]
#  [ 0.64414262  0.35585738]]

# %%
# generate evaluation metrics
print metrics.accuracy_score(y_test, predicted)
print "The ROC of training model is: ", metrics.roc_auc_score(y_test, predicted)


training_predict = model.predict(X_train)
print "The ROC of training model is: ", metrics.roc_auc_score(y_train, training_predict)
# Out:
# 0.603600153198
# The ROC of training model is:  0.566662166737
# The ROC of training model is:  0.5

# %%
print metrics.confusion_matrix(y_test, predicted)
print metrics.classification_report(y_test, predicted)
# Out:
# [[ 101   92]
#  [ 943 1475]]
#              precision    recall  f1-score   support
#
#         0.0       0.10      0.52      0.16       193
#         1.0       0.94      0.61      0.74      2418
#
# avg / total       0.88      0.60      0.70      2611

# %%
# evaluate the model using 10-fold cross-validation
scores = cross_val_score(LogisticRegression(), X, y, scoring='accuracy', cv=10)
print scores
print scores.mean()
# Out:
# [ 0.92684795  0.92684795  0.92684795  0.92684795  0.92723095  0.92723095
#   0.92723095  0.92720307  0.92720307  0.92720307]
# 0.92706938373
